# %%
import pandas as pd

# %%
# !ls ../../data
# Out:
# Business_Combinations_-_Failures_10_21_2021.csv
# Business_Combinations_10_21_2021.csv
# Conversions_11_7_2021.csv
# Interim_Mergers_&_Reorganizations_11_7_2021.csv
# Liquidations_10_21_2021.csv
# New_Institutions_10_21_2021.csv
# Summary_Events.csv
# bank-data.csv
# banklist.csv
# cb_structure.csv
# events_definitions.csv
# failed_banks_cleaned.csv
# si_structure.csv
# stress_index.csv

# %% [markdown]
# ## Interim Mergers and Reorgs

# %%
reorg_df = pd.read_csv("../../data/Interim_Mergers_&_Reorganizations_11_7_2021.csv")
reorg_df.head()
# Out:
#                ACQDATE  ACQYEAR  ASSISTED_PAYOUT_FLAG BANK_INSURED   CERT  \
# 0  2005-02-10T00:00:00     2005                     0            Y  27707
# 1  2001-08-08T00:00:00     2001                     0            Y   4821
# 2  2001-08-08T00:00:00     2001                     0            Y   4821
# 3  2001-03-23T00:00:00     2001                     0            Y  20740
# 4  2002-06-18T00:00:00     2002                     0            Y  14222
#
#    CHANGECODE                 CHANGECODE_DESC  \
# 0         820  PARTICIPATED IN REORGANIZATION
# 1         820  PARTICIPATED IN REORGANIZATION
# 2         820  PARTICIPATED IN REORGANIZATION
# 3         820  PARTICIPATED IN REORGANIZATION
# 4         820  PARTICIPATED IN REORGANIZATION
#
#               CHANGECODE_DESC_LONG CHARTAGENT  CHARTER_COM_TO_OTHER_FLAG  ...  \
# 0  Reorganized banking operations.      STATE                          0  ...
# 1  Reorganized banking operations.      STATE                          0  ...
# ...

# %%
reorg_df.CHANGECODE.unique()
# Out:
# array([820, 350, 360, 830])

# %%
reorg_df.groupby(reorg_df.CHANGECODE).count()
# Out:
#             ACQDATE  ACQYEAR  ASSISTED_PAYOUT_FLAG  BANK_INSURED  CERT  \
# CHANGECODE
# 350               3        3                     3             3     3
# 360               3        3                     3             3     3
# 820             875      875                   875           875   875
# 830              13       13                    13            13    13
#
#             CHANGECODE_DESC  CHANGECODE_DESC_LONG  CHARTAGENT  \
# CHANGECODE
# 350                       3                     3           3
# 360                       3                     3           3
# 820                     875                   875         875
# 830                      13                    13          13
#
#             CHARTER_COM_TO_OTHER_FLAG  CHARTER_COM_TO_OTS_FLAG  ...  \
# CHANGECODE                                                      ...
# 350                                 3                        3  ...
# ...

# %%
pd.set_option('display.max_colwidth', None)
reorg_df.loc[reorg_df.CHANGECODE==350]
# Out:
#                  ACQDATE  ACQYEAR  ASSISTED_PAYOUT_FLAG BANK_INSURED   CERT  \
# 105  2002-05-30T00:00:00     2002                     0            Y  57294
# 391  2008-07-11T00:00:00     2008                     0            Y  29730
# 477  2012-10-07T00:00:00     2012                     0            N  48817
#
#      CHANGECODE                     CHANGECODE_DESC  \
# 105         350  INSTITUTION ENTERS CONSERVATORSHIP
# 391         350  INSTITUTION ENTERS CONSERVATORSHIP
# 477         350  INSTITUTION ENTERS CONSERVATORSHIP
#
#                                        CHANGECODE_DESC_LONG CHARTAGENT  \
# 105  Institution entered into a government conservatorship.        OTS
# 391  Institution entered into a government conservatorship.        OTS
# 477  Institution entered into a government conservatorship.      STATE
#
#      CHARTER_COM_TO_OTHER_FLAG  ...  UNASSIST_COM_TO_COM_FLAG  \
# 105                          0  ...                         0
# ...

# %%
reorg_df.loc[reorg_df.CHANGECODE==830]
# Out:
#                  ACQDATE  ACQYEAR  ASSISTED_PAYOUT_FLAG BANK_INSURED   CERT  \
# 356  2009-02-03T00:00:00     2009                     0            Y  33143
# 385  2009-11-01T00:00:00     2009                     0            Y  34571
# 405  2009-08-30T00:00:00     2009                     0            Y   7213
# 406  2011-07-20T00:00:00     2011                     0            Y  18708
# 407  2009-12-14T00:00:00     2009                     0            Y  18923
# 408  2011-06-30T00:00:00     2011                     0            Y  23360
# 409  2011-07-20T00:00:00     2011                     0            Y  58180
# 413  2009-06-30T00:00:00     2009                     0            Y  27374
# 419  2009-04-26T00:00:00     2009                     0            Y   3510
# 420  2009-09-15T00:00:00     2009                     0            Y  25178
# 421  2014-09-30T00:00:00     2014                     0            Y  33318
# ...

# %%
reorg_df.loc[reorg_df.CHANGECODE==360]
# Out:
#                  ACQDATE  ACQYEAR  ASSISTED_PAYOUT_FLAG BANK_INSURED   CERT  \
# 278  2004-05-30T00:00:00     2004                     0            Y  57294
# 411  2009-03-19T00:00:00     2009                     0            Y  58912
# 630  9999-12-31T00:00:00     9999                     0            N  48817
#
#      CHANGECODE                       CHANGECODE_DESC  \
# 278         360  CONSERVATORSHIP INSTITUTION RESOLVED
# 411         360  CONSERVATORSHIP INSTITUTION RESOLVED
# 630         360  CONSERVATORSHIP INSTITUTION RESOLVED
#
#                                     CHANGECODE_DESC_LONG CHARTAGENT  \
# 278  Government conservatorship or bridge bank resolved.        OTS
# 411  Government conservatorship or bridge bank resolved.        OTS
# 630  Government conservatorship or bridge bank resolved.      STATE
#
#      CHARTER_COM_TO_OTHER_FLAG  ...  UNASSIST_COM_TO_COM_FLAG  \
# 278                          0  ...                         0
# ...

# %%
reorg_df.groupby(reorg_df.VOLUNTARY_LIQUIDATION_FLAG).count()
# Out:
#                             ACQDATE  ACQYEAR  ASSISTED_PAYOUT_FLAG  \
# VOLUNTARY_LIQUIDATION_FLAG
# 0                               894      894                   894
#
#                             BANK_INSURED  CERT  CHANGECODE  CHANGECODE_DESC  \
# VOLUNTARY_LIQUIDATION_FLAG
# 0                                    894   894         894              894
#
#                             CHANGECODE_DESC_LONG  CHARTAGENT  \
# VOLUNTARY_LIQUIDATION_FLAG
# 0                                            894         894
#
#                             CHARTER_COM_TO_OTHER_FLAG  ...  TRUST  \
# VOLUNTARY_LIQUIDATION_FLAG                             ...
# 0                                                 894  ...    308
#
#                             UNASSIST_COM_TO_COM_FLAG  \
# VOLUNTARY_LIQUIDATION_FLAG
# 0                                                894
#
#                             UNASSIST_COM_TO_OTS_FLAG  \
# VOLUNTARY_LIQUIDATION_FLAG
# ...

# %% [markdown]
# ## Conversions

# %%
df = pd.read_csv("../../data/Conversions_11_7_2021.csv")

conver_df = df.loc[conver_df['EFFYEAR']>1999]
conver_df.shape
# Out:
# (7493, 106)

# %%
conver_df.CHANGECODE.unique()
# Out:
# array([410, 440, 470, 420, 310, 320, 430, 150])

# %%
conver_df.CHANGECODE_DESC.unique()
# Out:
# array(['CHANGE IN INSURANCE STATUS', 'CHANGE IN ORGANIZATION TYPE',
#        'CHANGE IN PRIMARY REGULATORY AGENCY',
#        'CHANGE IN CHARTERING AGENT',
#        'INSTITUTION BECOMES A MEMBER OF FRS (FEDERAL RESERVE SYSTEM)',
#        'INSTITUTION WITHDRAWS FROM FRS (FEDERAL RESERVE SYSTEM)',
#        'CHANGE IN CLASS',
#        'CERT CHANGED FROM OLD CERT BY ADMINISTRATIVE ORDER'], dtype=object)

# %%
conver_df.groupby(conver_df['CHANGECODE_DESC']).count()
# Out:
#                                                               ACQDATE  \
# CHANGECODE_DESC
# CERT CHANGED FROM OLD CERT BY ADMINISTRATIVE ORDER                  5
# CHANGE IN CHARTERING AGENT                                       1173
# CHANGE IN CLASS                                                  1856
# CHANGE IN INSURANCE STATUS                                        102
# CHANGE IN ORGANIZATION TYPE                                       843
# CHANGE IN PRIMARY REGULATORY AGENCY                              2389
# INSTITUTION BECOMES A MEMBER OF FRS (FEDERAL RESERVE SYSTEM)      669
# INSTITUTION WITHDRAWS FROM FRS (FEDERAL RESERVE SYSTEM)           456
#
#                                                               ACQYEAR  \
# CHANGECODE_DESC
# CERT CHANGED FROM OLD CERT BY ADMINISTRATIVE ORDER                  5
# CHANGE IN CHARTERING AGENT                                       1173
# CHANGE IN CLASS                                                  1856
# ...

# %%
conver_df.loc[conver_df['CHANGECODE_DESC']=='CHANGE IN INSURANCE STATUS']
# Out:
#                   ACQDATE  ACQYEAR  ASSISTED_PAYOUT_FLAG BANK_INSURED   CERT  \
# 75    2006-03-29T00:00:00     2006                     0            Y  35497
# 81    2000-01-29T00:00:00     2000                     0            Y  35498
# 154   2006-03-29T00:00:00     2006                     0            Y  28770
# 759   2000-12-30T00:00:00     2000                     0            Y  91325
# 787   2000-02-04T00:00:00     2000                     0            N  27391
# ...                   ...      ...                   ...          ...    ...
# 8128  2020-09-30T00:00:00     2020                     0            N  28384
# 8132  2020-09-30T00:00:00     2020                     0            N  31257
# 8139  2020-09-30T00:00:00     2020                     0            N  28384
# 8143  2020-09-30T00:00:00     2020                     0            N  31257
# 8144  2020-09-30T00:00:00     2020                     0            N  28807
#
# ...

# %%
conver_df.loc[
    (conver_df['CHANGECODE_DESC']=='CHANGE IN INSURANCE STATUS') & 
    (conver_df['CHANGECODE_DESC_LONG']=='Voluntarily relinquished FDIC insurance.')]
# Out:
#                   ACQDATE  ACQYEAR  ASSISTED_PAYOUT_FLAG BANK_INSURED   CERT  \
# 787   2000-02-04T00:00:00     2000                     0            N  27391
# 831   2000-03-31T00:00:00     2000                     0            N  33798
# 958   2000-06-19T00:00:00     2000                     0            N  33658
# 961   2000-06-19T00:00:00     2000                     0            N  33658
# 1131  2002-01-14T00:00:00     2002                     0            N  27350
# ...                   ...      ...                   ...          ...    ...
# 8128  2020-09-30T00:00:00     2020                     0            N  28384
# 8132  2020-09-30T00:00:00     2020                     0            N  31257
# 8139  2020-09-30T00:00:00     2020                     0            N  28384
# 8143  2020-09-30T00:00:00     2020                     0            N  31257
# 8144  2020-09-30T00:00:00     2020                     0            N  28807
#
# ...

# %%
conver_df.CERT
# Out:
# 75      35497
# 76      35497
# 77      35497
# 81      35498
# 82      35498
#         ...
# 8301    34383
# 8302    27989
# 8303    27989
# 8304    27989
# 8305    27989
# Name: CERT, Length: 7493, dtype: int64

# %%
cols = ['EFFYEAR', "CLASS_TYPE", 'CERT']
relinquished = conver_df.loc[
    (conver_df['CHANGECODE_DESC_LONG']=='Voluntarily relinquished FDIC insurance.')][cols]
relinquished.shape
# Out:
# (82, 3)

# %%
relinquished.head()
# Out:
#       EFFYEAR CLASS_TYPE   CERT
# 787      2000        NaN  27391
# 831      2000        NaN  33798
# 958      2000        NaN  33658
# 961      2000        NaN  33658
# 1131     2000        NaN  27350

# %%
relinquished.groupby('EFFYEAR')['CERT'].count().plot(kind='bar')

# %%
conver_df.loc[conver_df['VOLUNTARY_LIQUIDATION_FLAG'] != 0]
# Out:
# Empty DataFrame
# ...
